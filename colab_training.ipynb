# %% [markdown]
# # Improved cGAN Training — CIFAR-10
#
# Run cells in order. Uses T4/A100 GPU if available.

# %%
# 1. Clone your repo and navigate to project
# !git clone https://github.com/hussnain-raza-dr/Scientific-Computing-Project-Master.git
# %cd Scientific-Computing-Project-Master

# %%
# 2. Install GPU PyTorch + dependencies
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118 -q
# !pip install pyyaml matplotlib -q

import torch
print(f'PyTorch: {torch.__version__}')
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only"}')

# %%
# 3. Train improved model (WGAN-GP)
# !python training/train.py --config config/improved_config.yaml --arch improved

# %%
# 4. OR: Run hyperparameter search stage 1 first (30 epochs each config)
# !python training/hyperparameter_search.py --stage 1 --epochs 30

# %%
# 5. View training curves
from IPython.display import Image
Image('results/training_curves.png')

# %%
# 6. View generated samples
Image('results/final_samples.png')

# %%
# 7. View class variation
Image('results/class_variation.png')

# %%
# 8. View latent interpolation
Image('results/latent_interpolation.png')

# %%
# 9. Mount Google Drive to save checkpoints persistently
from google.colab import drive
drive.mount('/content/drive')
# !cp -r checkpoints/ /content/drive/MyDrive/cgan_checkpoints/
# !cp -r results/ /content/drive/MyDrive/cgan_results/
